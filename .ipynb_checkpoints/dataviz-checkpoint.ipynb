# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/clean_rw_food_prices.csv')
df.head()
# Out:
#          date            admin1   admin2            market  latitude  \
# 0  2016-09-15  Eastern Province  Gatsibo  Nyabiheke (Camp) -1.595355
# 1  2016-09-15  Eastern Province  Gatsibo  Nyabiheke (Camp) -1.595355
# 2  2016-09-15  Eastern Province  Gatsibo  Nyabiheke (Camp) -1.595355
# 3  2016-09-15  Eastern Province  Gatsibo  Nyabiheke (Camp) -1.595355
# 4  2016-09-15  Eastern Province  Gatsibo  Nyabiheke (Camp) -1.595355
#
#    longitude            category         commodity unit priceflag pricetype  \
# 0  30.259304  cereals and tubers           Cassava   KG    actual    Retail
# 1  30.259304  cereals and tubers     Cassava flour   KG    actual    Retail
# 2  30.259304  cereals and tubers             Maize   KG    actual    Retail
# 3  30.259304  cereals and tubers          Potatoes   KG    actual    Retail
# 4  30.259304  cereals and tubers  Potatoes (Irish)   KG    actual    Retail
#
#   currency  price  usdprice
# 0      RWF  200.0    0.1909
# 1      RWF  400.0    0.3818
# ...

# %%
df.tail()
# Out:
#             date            admin1   admin2         market  latitude  \
# 4576  2022-10-15  Western Province  Karongi  Kiziba (Camp)  -2.12981
# 4577  2022-10-15  Western Province  Karongi  Kiziba (Camp)  -2.12981
# 4578  2022-10-15  Western Province  Karongi  Kiziba (Camp)  -2.12981
# 4579  2022-10-15  Western Province  Karongi  Kiziba (Camp)  -2.12981
# 4580  2022-10-15  Western Province  Karongi  Kiziba (Camp)  -2.12981
#
#       longitude            category                               commodity  \
# 4576  29.355169  cereals and tubers              Rice (imported, Tanzanian)
# 4577  29.355169  cereals and tubers  Rice (long grain, high quality, local)
# 4578  29.355169  miscellaneous food                                    Salt
# 4579  29.355169        oil and fats                                     Oil
# 4580  29.355169     pulses and nuts                             Beans (dry)
#
#      unit  priceflag pricetype currency    price  usdprice
# ...
